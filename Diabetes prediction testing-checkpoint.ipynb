# %% [markdown]
# # Data Processing

# %%
import pandas, seaborn

df = pandas.read_csv('../Downloads/diabetes.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1372\2764039862.py in <module>
#       1 import pandas, seaborn
#       2
# ----> 3 df = pandas.read_csv('../Downloads/diabetes.csv')
#       4 df
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Downloads/diabetes.csv'

# %% [markdown]
# Counting the number of zeros features

# %%
columns = ["Glucose", "BloodPressure", "SkinThickness", "BMI", "DiabetesPedigreeFunction", "Age"]

def counting_zero():
    for i in columns:
        count=0
        count = (df[i] == 0).sum()
        print(i +" : "+ str(count))
        
counting_zero()
# Out:
# Glucose : 5
# BloodPressure : 35
# SkinThickness : 227
# BMI : 11
# DiabetesPedigreeFunction : 0
# Age : 0

# %% [markdown]
# Removing feature SkinThickness as it has a lot of zero values

# %%
df = df.drop(columns=['SkinThickness'])
df
# Out:
#      Pregnancies  Glucose  BloodPressure  Insulin   BMI  \
# 0              6      148             72        0  33.6
# 1              1       85             66        0  26.6
# 2              8      183             64        0  23.3
# 3              1       89             66       94  28.1
# 4              0      137             40      168  43.1
# ..           ...      ...            ...      ...   ...
# 763           10      101             76      180  32.9
# 764            2      122             70        0  36.8
# 765            5      121             72      112  26.2
# 766            1      126             60        0  30.1
# 767            1       93             70        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 8 columns]

# %% [markdown]
# Removing zero values for features which should not have zero values

# %%
Q = (df['Glucose']>0) & (df['BloodPressure']>0) & (df['BMI']>0) & (df['Age']>0)
new_data = df[Q]
new_data
# Out:
#      Pregnancies  Glucose  BloodPressure  Insulin   BMI  \
# 0              6      148             72        0  33.6
# 1              1       85             66        0  26.6
# 2              8      183             64        0  23.3
# 3              1       89             66       94  28.1
# 4              0      137             40      168  43.1
# ..           ...      ...            ...      ...   ...
# 763           10      101             76      180  32.9
# 764            2      122             70        0  36.8
# 765            5      121             72      112  26.2
# 766            1      126             60        0  30.1
# 767            1       93             70        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [724 rows x 8 columns]

# %%
seaborn.heatmap(new_data.corr(), vmin = -1, vmax = 1, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Modeling

# %%
x = new_data.drop(columns=['Outcome'])
y = new_data["Outcome"]
#Splitting train test data 80 20 ratio
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2)

# %%
train_x.shape,test_x.shape,train_y.shape,test_y.shape
# Out:
# ((579, 7), (145, 7), (579,), (145,))

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,make_scorer
from sklearn.model_selection import cross_validate


def tn(y_true, y_pred): return confusion_matrix(y_true, y_pred)[0, 0]
def fp(y_true, y_pred): return confusion_matrix(y_true, y_pred)[0, 1]
def fn(y_true, y_pred): return confusion_matrix(y_true, y_pred)[1, 0]
def tp(y_true, y_pred): return confusion_matrix(y_true, y_pred)[1, 1]

#cross validation purpose
scoring = {'accuracy': make_scorer(accuracy_score)}
scoring = {'tp': make_scorer(tp), 'tn': make_scorer(tn),
           'fp': make_scorer(fp), 'fn': make_scorer(fn)}

def display_result(result):
    print("TP: ",result['test_tp'])
    print("TN: ",result['test_tn'])
    print("FN: ",result['test_fn'])
    print("FP: ",result['test_fp'])

# %%
#Naive Bayes Theorem
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

clf=GaussianNB()
clf.fit(train_x,train_y)
y_pred=clf.predict(test_x)
#find accuracy
acc=[]
ac=accuracy_score(test_y,y_pred)
acc.append(ac)
print("\nAccuracy =",ac)

#cross val score
result=cross_validate(clf,train_x,train_y,scoring=scoring,cv=10)
display_result(result)

print ("Classification Report\n")
# labels for set 1=True to upper left and 0 = False to lower right
print ("{0}".format(metrics.classification_report( test_y,y_pred)))

#display predicted values uncomment below line
pandas.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()

# Displaying ROC-AUC curve
import matplotlib.pyplot as plt
from sklearn import metrics

roauc = []
scr = metrics.roc_auc_score(test_y, y_pred).round(3)
roauc.append(scr)
print('ROC-AUC Score:', scr)
metrics.RocCurveDisplay.from_predictions(test_y, y_pred)
plt.show()
# Out:
# Accuracy = 0.7793103448275862
# TP:  [13 13 10 11 11 15 11 12 15 12]
# TN:  [32 34 28 32 31 32 33 29 35 30]
# FN:  [ 7  7 10  9  9  5  9  8  6  8]
# FP:  [ 6  4 10  6  7  6  5  9  2  7]
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84        97
#            1       0.68      0.62      0.65        48
#
#     accuracy                           0.78       145
#    macro avg       0.75      0.74      0.75       145
# weighted avg       0.78      0.78      0.78       145
#
# ROC-AUC Score: 0.74

# %%
#Decision Tree Classification Algorithm 
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

clf=DecisionTreeClassifier(random_state=1234)
clf.fit(train_x,train_y)
y_pred=clf.predict(test_x)

#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)
print("\nAccuracy =",ac)

#cross val score
result=cross_validate(clf,train_x,train_y,scoring=scoring,cv=10)
display_result(result)
print ("Classification Report\n")
# labels for set 1=True to upper left and 0 = False to lower right
print ("{0}".format(metrics.classification_report( test_y,y_pred)))

#display predicted values uncomment below line
pandas.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()

# Displaying ROC-AUC curve
import matplotlib.pyplot as plt
from sklearn import metrics

scr = metrics.roc_auc_score(test_y, y_pred).round(3)
roauc.append(scr)
print('ROC-AUC Score:', scr)
metrics.RocCurveDisplay.from_predictions(test_y, y_pred)
plt.show()
# Out:
# Accuracy = 0.7103448275862069
# TP:  [11 11 15 13  9 10  9  9 16 12]
# TN:  [30 33 28 30 31 28 30 24 31 29]
# FN:  [ 9  9  5  7 11 10 11 11  5  8]
# FP:  [ 8  5 10  8  7 10  8 14  6  8]
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.74      0.77        97
#            1       0.55      0.65      0.60        48
#
#     accuracy                           0.71       145
#    macro avg       0.68      0.69      0.69       145
# weighted avg       0.72      0.71      0.72       145
#
# ROC-AUC Score: 0.694

# %%
#Logistic Regression Classification Algorithm 
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

clf=LogisticRegression()
clf.fit(train_x,train_y)
y_pred=clf.predict(test_x)

#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)
print("\nAccuracy =",ac)

#cross val score
result=cross_validate(clf,train_x,train_y,scoring=scoring,cv=10)
display_result(result)
print ("Classification Report\n")
# labels for set 1=True to upper left and 0 = False to lower right
print ("{0}".format(metrics.classification_report( test_y,y_pred)))

#display predicted values uncomment below line
pandas.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()

# Displaying ROC-AUC curve
import matplotlib.pyplot as plt
from sklearn import metrics

scr = metrics.roc_auc_score(test_y, y_pred).round(3)
roauc.append(scr)
print('ROC-AUC Score:', scr)
metrics.RocCurveDisplay.from_predictions(test_y, y_pred)
plt.show()
# Out:
# C:\Users\alias\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\alias\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\alias\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\alias\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\alias\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\alias\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy = 0.7931034482758621
# C:\Users\alias\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\alias\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\alias\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\alias\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\alias\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# TP:  [10 11 11 10 11 13 10 12 14  9]
# TN:  [35 35 31 35 33 33 35 28 34 31]
# FN:  [10  9  9 10  9  7 10  8  7 11]
# FP:  [ 3  3  7  3  5  5  3 10  3  6]
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85        97
#            1       0.74      0.58      0.65        48
#
#     accuracy                           0.79       145
#    macro avg       0.77      0.74      0.75       145
# weighted avg       0.79      0.79      0.79       145
#
# ROC-AUC Score: 0.74

# %%
# Linear Discriminant Analysis (LDA) Classification Algorithm 
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn import metrics

clf=LinearDiscriminantAnalysis()
clf.fit(train_x,train_y)
y_pred=clf.predict(test_x)

#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)
print("\nAccuracy =",ac)

#cross val score
result=cross_validate(clf,train_x,train_y,scoring=scoring,cv=10)
display_result(result)
print ("Classification Report\n")
# labels for set 1=True to upper left and 0 = False to lower right
print ("{0}".format(metrics.classification_report( test_y,y_pred)))

#display predicted values uncomment below line
pandas.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()

# Displaying ROC-AUC curve
import matplotlib.pyplot as plt
from sklearn import metrics

scr = metrics.roc_auc_score(test_y, y_pred).round(3)
roauc.append(scr)
print('ROC-AUC Score:', scr)
metrics.RocCurveDisplay.from_predictions(test_y, y_pred)
plt.show()
# Out:
# Accuracy = 0.7862068965517242
# TP:  [10 11 11 10 11 14 11 11 14 10]
# TN:  [34 36 31 35 32 33 34 28 35 31]
# FN:  [10  9  9 10  9  6  9  9  7 10]
# FP:  [ 4  2  7  3  6  5  4 10  2  6]
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85        97
#            1       0.73      0.56      0.64        48
#
#     accuracy                           0.79       145
#    macro avg       0.77      0.73      0.74       145
# weighted avg       0.78      0.79      0.78       145
#
# ROC-AUC Score: 0.73

# %%
# Quadratic Discriminant Analysis Classification Algorithm 
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn import metrics

clf=QuadraticDiscriminantAnalysis()
clf.fit(train_x,train_y)
y_pred=clf.predict(test_x)

#find accuracy
ac=accuracy_score(test_y,y_pred)
acc.append(ac)
print("\nAccuracy =",ac)

#cross val score
result=cross_validate(clf,train_x,train_y,scoring=scoring,cv=10)
display_result(result)
print ("Classification Report\n")
# labels for set 1=True to upper left and 0 = False to lower right
print ("{0}".format(metrics.classification_report( test_y,y_pred)))

#display predicted values uncomment below line
pandas.DataFrame(data={'Actual':test_y,'Predicted':y_pred}).head()

# Displaying ROC-AUC curve
import matplotlib.pyplot as plt
from sklearn import metrics

scr = metrics.roc_auc_score(test_y, y_pred).round(3)
roauc.append(scr)
print('ROC-AUC Score:', scr)
metrics.RocCurveDisplay.from_predictions(test_y, y_pred)
plt.show()
# Out:
# Accuracy = 0.7586206896551724
# TP:  [11 11 10 11 10 12 10 10 13 12]
# TN:  [33 36 30 33 31 32 31 27 33 31]
# FN:  [ 9  9 10  9 10  8 10 10  8  8]
# FP:  [ 5  2  8  5  7  6  7 11  4  6]
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82        97
#            1       0.64      0.62      0.63        48
#
#     accuracy                           0.76       145
#    macro avg       0.73      0.72      0.73       145
# weighted avg       0.76      0.76      0.76       145
#
# ROC-AUC Score: 0.725

# %%
# Visuallizing results of our models performance using ROC matrix on testing data.

import matplotlib.pyplot as plt
ax=plt.figure(figsize=(9,5))
plt.bar(['Naivye Bayes','Decision Tree', 'Logistic Regression', 'LDA', 'QDA'], roauc)
plt.ylabel('Accuracy Score')
plt.xlabel('Algortihms')

for i in range(len(roauc)):
    plt.text(i, roauc[i], roauc[i], ha = 'center', va = 'bottom')
    
plt.show()

# %%
# Visualizing accuracy score of our model.

import matplotlib.pyplot as plt
ax=plt.figure(figsize=(9,5))
plt.bar(['Naivye Bayes','Decision Tree', 'Logistic Regression', 'LDA', 'QDA'], acc, label = 'Accuracy')
plt.ylabel('Accuracy Score')
plt.xlabel('Algortihms')

for i in range(len(acc)):
    plt.text(i, acc[i], acc[i].round(3), ha = 'center', va = 'bottom')
    
plt.show()

# %% [markdown]
# # Reference

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html#sklearn.metrics.roc_auc_score
# https://www.youtube.com/watch?v=O_5kf_Kb684
